# %% [markdown]
# # Projet maison n° 5

# %% [markdown]
# Par au moins un opérateurOn s'intéresse au fichier sur la Couverture 2G, 3G, 4G en France par opérateur de juillet 2015 fourni par l'ARCEP : "couverture-2g-3g-4g-en-france-par-operateur-juillet-2015.csv".
#
# [°] Ce fichier donne le taux de couverture par commune, par opérateur (Orange France, Bouygues Telecom, SFR, Free Mobile, Tout Opérateur), par type de couverture (Couverture population, Couverture surfacique) et par réseau (2G, 3G, 4G).
#
# 1. Chargez le fichier dans un DataFrame.
# 2. Transformez ce DataFrame large en un DataFrame long en isolant les colonnes d'identification d'une part et les colonnes de valeurs de couverture d'autre part.
# 3. Rajoutez 3 colonnes "Opérateur", "Type Couverture" et "Réseau" calculées à partir de la colonne "variable" obtenue en 2 (utilisez les valeurs indiquées entre parenthèses ci-dessus [°], ces valeurs sont utilisées dans les tests).
# 4. A partir de ce DataFrame, obtenez un objet de type Series dont les valeurs correspondent à la colonne "value" obtenue en 2 et dont le multi-index contient les autres colonnes du DataFrame sauf la colonne "variable" obtenue en 2. Puis remontez les index "Opérateur", "Type Couverture" et "Réseau" en colonnes multi-indexées. Vous devez obtenir un DataFrame avec 7 niveaux d'index et 3 niveaux de colonnes.
# 5. Chargez le DataFrame des communes déjà utilisé ("correspondance-code-insee-code-postal.csv") et effectuez une jointure sur le code INSEE avec le DataFrame obtenu en 3.
# 6. Pour le réseau 4G et la couverture surfacique, calculez la moyenne des couvertures par statut de commune et par opérateur. Pour quel couple (statut, opérateur) a-t-on la moyenne de la couverture la plus faible ?
#
# **Nota bene** : les différentes instructions doivent être réalisées dans les fonctions prédéfinies pour passer les tests. Il est néanmoins possible de définir des fonctions annexes appelées par les fonctions prédéfinies.

# %%
# import
import pandas as pd

# %%
# 1) Chargez le fichier dans un DataFrame
def load_data():
    df = pd.read_csv("couverture-2g-3g-4g-en-france-par-operateur-juillet-2015.csv", sep=";")
    return df

# %%
# load_data
load_data()
# Out:
#       CODE POSTAL CODE INSEE          NOM COMMUNE CODE DEPARTEMENT  \
# 0           17510      17105               CHIVES               17
# 1           17600      17112            LA CLISSE               17
# 2           17150      17116               CONSAC               17
# 3           17130      17118             CORIGNAC               17
# 4           17330      17124              COURANT               17
# ...           ...        ...                  ...              ...
# 36589       70000      70378              NAVENNE               70
# 36590       70000      70388   NOIDANS-LES-VESOUL               70
# 36591       70100      70389               NOIRON               70
# 36592       70500      70399                ORMOY               70
# 36593       70130      70418  LE PONT-DE-PLANCHES               70
#
#        SURFACE COMMUNE (km²)  POPULATION COMMUNE  \
# 0                  20.642005              355.32
# 1                   4.896771              591.78
# 2                   8.915911              239.74
# 3                  10.850210              358.69
# 4                  15.586269              371.00
# ...                      ...                 ...
# 36589               3.826265             1847.69
# 36590               8.634594             2159.19
# 36591               5.768295               64.01
# 36592              19.577164              224.76
# 36593               6.379713              213.99
#
#        Orange France Couverture population 4G  \
# 0                                        0.00
# 1                                        0.09
# 2                                        0.00
# 3                                        0.00
# 4                                        0.00
# ...                                       ...
# 36589                                    1.00
# 36590                                    0.99
# 36591                                    0.00
# 36592                                    0.00
# 36593                                    0.00
#
#        Bouygues Telecom Couverture population 4G  \
# 0                                           0.00
# 1                                           0.00
# 2                                           0.00
# 3                                           0.00
# 4                                           0.00
# ...                                          ...
# 36589                                       1.00
# 36590                                       0.95
# 36591                                       0.00
# 36592                                       0.00
# 36593                                       0.00
#
#        SFR Couverture population 4G  Free Mobile Couverture population 4G  \
# 0                              0.00                                   0.0
# 1                              0.00                                   0.0
# 2                              0.00                                   0.0
# 3                              0.00                                   0.0
# 4                              0.00                                   0.0
# ...                             ...                                   ...
# 36589                          0.99                                   0.0
# 36590                          0.36                                   0.0
# 36591                          0.00                                   0.0
# 36592                          0.00                                   0.0
# 36593                          0.00                                   0.0
#
#        ...  Bouygues Telecom Couverture population 2G  \
# 0      ...                                       1.00
# 1      ...                                       1.00
# 2      ...                                       1.00
# 3      ...                                       0.63
# 4      ...                                       1.00
# ...    ...                                        ...
# 36589  ...                                       1.00
# 36590  ...                                       1.00
# 36591  ...                                       1.00
# 36592  ...                                       1.00
# 36593  ...                                       1.00
#
#        SFR Couverture population 2G  Free Mobile Couverture population 2G  \
# 0                               1.0                                   1.0
# 1                               1.0                                   1.0
# 2                               1.0                                   1.0
# 3                               1.0                                   1.0
# 4                               1.0                                   1.0
# ...                             ...                                   ...
# 36589                           1.0                                   1.0
# 36590                           1.0                                   1.0
# 36591                           1.0                                   1.0
# 36592                           1.0                                   1.0
# 36593                           1.0                                   1.0
#
#        Par au moins un opérateur Couverture population 2G  \
# 0                                                    1.0
# 1                                                    1.0
# 2                                                    1.0
# 3                                                    1.0
# 4                                                    1.0
# ...                                                  ...
# 36589                                                1.0
# 36590                                                1.0
# 36591                                                1.0
# 36592                                                1.0
# 36593                                                1.0
#
#        Orange France Couverture surfacique 2G  \
# 0                                        1.00
# 1                                        1.00
# 2                                        1.00
# 3                                        0.99
# 4                                        1.00
# ...                                       ...
# 36589                                    1.00
# 36590                                    1.00
# 36591                                    1.00
# 36592                                    1.00
# 36593                                    1.00
#
#        Bouygues Telecom Couverture surfacique 2G  \
# 0                                           0.99
# 1                                           1.00
# 2                                           1.00
# 3                                           0.85
# 4                                           1.00
# ...                                          ...
# 36589                                       1.00
# 36590                                       1.00
# 36591                                       0.98
# 36592                                       0.99
# 36593                                       0.98
#
#        SFR Couverture surfacique 2G  Free Mobile Couverture surfacique 2G  \
# 0                              1.00                                  1.00
# 1                              1.00                                  1.00
# 2                              1.00                                  1.00
# 3                              1.00                                  0.99
# 4                              1.00                                  1.00
# ...                             ...                                   ...
# 36589                          1.00                                  1.00
# 36590                          1.00                                  1.00
# 36591                          0.96                                  1.00
# 36592                          0.98                                  1.00
# 36593                          0.98                                  1.00
#
#        Par au moins un opérateur Couverture surfacique 2G  \
# 0                                                    1.0
# 1                                                    1.0
# 2                                                    1.0
# 3                                                    1.0
# 4                                                    1.0
# ...                                                  ...
# 36589                                                1.0
# 36590                                                1.0
# 36591                                                1.0
# 36592                                                1.0
# 36593                                                1.0
#
#                           coordonnees
# 0      45.9508835378, -0.121918052323
# 1       45.7320429784, -0.75493581331
# 2      45.4182495786, -0.588917528415
# 3       45.2448604983, -0.39280322021
# 4      46.0375312829, -0.587834905531
# ...                               ...
# 36589     47.6030208472, 6.1618556725
# 36590    47.6097514089, 6.11842989879
# 36591    47.3828510502, 5.62597938451
# 36592    47.8850612988, 5.99402771513
# 36593    47.5374721676, 5.92263244824
#
# [36594 rows x 37 columns]

# %%
# 2) Transformez ce DataFrame large en un DataFrame long
def data_wide2long():
    df = load_data()
    df = df.melt(id_vars=list(df.columns[:6]) + ["coordonnees"],
                 value_vars=list(df.columns[6:-1]))
    return df

# %%
# data_wide2long
data_wide2long()
# Out:
#         CODE POSTAL CODE INSEE          NOM COMMUNE CODE DEPARTEMENT  \
# 0             17510      17105               CHIVES               17
# 1             17600      17112            LA CLISSE               17
# 2             17150      17116               CONSAC               17
# 3             17130      17118             CORIGNAC               17
# 4             17330      17124              COURANT               17
# ...             ...        ...                  ...              ...
# 1097815       70000      70378              NAVENNE               70
# 1097816       70000      70388   NOIDANS-LES-VESOUL               70
# 1097817       70100      70389               NOIRON               70
# 1097818       70500      70399                ORMOY               70
# 1097819       70130      70418  LE PONT-DE-PLANCHES               70
#
#          SURFACE COMMUNE (km²)  POPULATION COMMUNE  \
# 0                    20.642005              355.32
# 1                     4.896771              591.78
# 2                     8.915911              239.74
# 3                    10.850210              358.69
# 4                    15.586269              371.00
# ...                        ...                 ...
# 1097815               3.826265             1847.69
# 1097816               8.634594             2159.19
# 1097817               5.768295               64.01
# 1097818              19.577164              224.76
# 1097819               6.379713              213.99
#
#                             coordonnees  \
# 0        45.9508835378, -0.121918052323
# 1         45.7320429784, -0.75493581331
# 2        45.4182495786, -0.588917528415
# 3         45.2448604983, -0.39280322021
# 4        46.0375312829, -0.587834905531
# ...                                 ...
# 1097815     47.6030208472, 6.1618556725
# 1097816    47.6097514089, 6.11842989879
# 1097817    47.3828510502, 5.62597938451
# 1097818    47.8850612988, 5.99402771513
# 1097819    47.5374721676, 5.92263244824
#
#                                                   variable  value
# 0                   Orange France Couverture population 4G   0.00
# 1                   Orange France Couverture population 4G   0.09
# 2                   Orange France Couverture population 4G   0.00
# 3                   Orange France Couverture population 4G   0.00
# 4                   Orange France Couverture population 4G   0.00
# ...                                                    ...    ...
# 1097815  Par au moins un opérateur Couverture surfaciqu...   1.00
# 1097816  Par au moins un opérateur Couverture surfaciqu...   1.00
# 1097817  Par au moins un opérateur Couverture surfaciqu...   1.00
# 1097818  Par au moins un opérateur Couverture surfaciqu...   1.00
# 1097819  Par au moins un opérateur Couverture surfaciqu...   1.00
#
# [1097820 rows x 9 columns]

# %%
# 3) Rajoutez 3 colonnes "Opérateur", "Type Couverture" et "Réseau"
def data_add3columns():
    df = data_wide2long()
    df[["Opérateur", "Type Couverture", "Réseau"]] = df["variable"].str.extract("^(.*) (Couverture \S+) ([0-9]G)")
    df["Opérateur"] = df["Opérateur"].replace("Par au moins un opérateur", "Tout Opérateur")
    return df.drop("variable", axis=1)

# %%
# data_add3columns
data_add3columns()
# Out:
#         CODE POSTAL CODE INSEE          NOM COMMUNE CODE DEPARTEMENT  \
# 0             17510      17105               CHIVES               17
# 1             17600      17112            LA CLISSE               17
# 2             17150      17116               CONSAC               17
# 3             17130      17118             CORIGNAC               17
# 4             17330      17124              COURANT               17
# ...             ...        ...                  ...              ...
# 1097815       70000      70378              NAVENNE               70
# 1097816       70000      70388   NOIDANS-LES-VESOUL               70
# 1097817       70100      70389               NOIRON               70
# 1097818       70500      70399                ORMOY               70
# 1097819       70130      70418  LE PONT-DE-PLANCHES               70
#
#          SURFACE COMMUNE (km²)  POPULATION COMMUNE  \
# 0                    20.642005              355.32
# 1                     4.896771              591.78
# 2                     8.915911              239.74
# 3                    10.850210              358.69
# 4                    15.586269              371.00
# ...                        ...                 ...
# 1097815               3.826265             1847.69
# 1097816               8.634594             2159.19
# 1097817               5.768295               64.01
# 1097818              19.577164              224.76
# 1097819               6.379713              213.99
#
#                             coordonnees  value       Opérateur  \
# 0        45.9508835378, -0.121918052323   0.00   Orange France
# 1         45.7320429784, -0.75493581331   0.09   Orange France
# 2        45.4182495786, -0.588917528415   0.00   Orange France
# 3         45.2448604983, -0.39280322021   0.00   Orange France
# 4        46.0375312829, -0.587834905531   0.00   Orange France
# ...                                 ...    ...             ...
# 1097815     47.6030208472, 6.1618556725   1.00  Tout Opérateur
# 1097816    47.6097514089, 6.11842989879   1.00  Tout Opérateur
# 1097817    47.3828510502, 5.62597938451   1.00  Tout Opérateur
# 1097818    47.8850612988, 5.99402771513   1.00  Tout Opérateur
# 1097819    47.5374721676, 5.92263244824   1.00  Tout Opérateur
#
#                Type Couverture Réseau
# 0        Couverture population     4G
# 1        Couverture population     4G
# 2        Couverture population     4G
# 3        Couverture population     4G
# 4        Couverture population     4G
# ...                        ...    ...
# 1097815  Couverture surfacique     2G
# 1097816  Couverture surfacique     2G
# 1097817  Couverture surfacique     2G
# 1097818  Couverture surfacique     2G
# 1097819  Couverture surfacique     2G
#
# [1097820 rows x 11 columns]

# %%
# 4) Transformez ce DataFrame en multi-index
def data_multi_index():
    df = data_add3columns()
    df = df.set_index(list(df.columns[:7]) + list(df.columns[8:]))
    df = df.unstack(["Opérateur", "Type Couverture", "Réseau"]).droplevel(0, axis=1)
    return df

# %%
# data_multi_index
data_multi_index()

# %%
# 5) Effectuez une jointure sur le code INSEE
def data_join_geo():
    geo = pd.read_csv("correspondance-code-insee-code-postal.csv", sep=';',usecols=range(11))
    geo.rename(columns={'Code INSEE': 'CODE INSEE'}, inplace=True)
    df = data_add3columns()
    df = df.merge(geo, on="CODE INSEE")
    return df

# %%
# data_join_geo
data_join_geo()
# Out:
#         CODE POSTAL CODE INSEE          NOM COMMUNE CODE DEPARTEMENT  \
# 0             17510      17105               CHIVES               17
# 1             17510      17105               CHIVES               17
# 2             17510      17105               CHIVES               17
# 3             17510      17105               CHIVES               17
# 4             17510      17105               CHIVES               17
# ...             ...        ...                  ...              ...
# 1097815       70130      70418  LE PONT-DE-PLANCHES               70
# 1097816       70130      70418  LE PONT-DE-PLANCHES               70
# 1097817       70130      70418  LE PONT-DE-PLANCHES               70
# 1097818       70130      70418  LE PONT-DE-PLANCHES               70
# 1097819       70130      70418  LE PONT-DE-PLANCHES               70
#
#          SURFACE COMMUNE (km²)  POPULATION COMMUNE  \
# 0                    20.642005              355.32
# 1                    20.642005              355.32
# 2                    20.642005              355.32
# 3                    20.642005              355.32
# 4                    20.642005              355.32
# ...                        ...                 ...
# 1097815               6.379713              213.99
# 1097816               6.379713              213.99
# 1097817               6.379713              213.99
# 1097818               6.379713              213.99
# 1097819               6.379713              213.99
#
#                             coordonnees  value         Opérateur  \
# 0        45.9508835378, -0.121918052323   0.00     Orange France
# 1        45.9508835378, -0.121918052323   0.00  Bouygues Telecom
# 2        45.9508835378, -0.121918052323   0.00               SFR
# 3        45.9508835378, -0.121918052323   0.00       Free Mobile
# 4        45.9508835378, -0.121918052323   0.00    Tout Opérateur
# ...                                 ...    ...               ...
# 1097815    47.5374721676, 5.92263244824   1.00     Orange France
# 1097816    47.5374721676, 5.92263244824   0.98  Bouygues Telecom
# 1097817    47.5374721676, 5.92263244824   0.98               SFR
# 1097818    47.5374721676, 5.92263244824   1.00       Free Mobile
# 1097819    47.5374721676, 5.92263244824   1.00    Tout Opérateur
#
#                Type Couverture  ... Code Postal              Commune  \
# 0        Couverture population  ...       17510               CHIVES
# 1        Couverture population  ...       17510               CHIVES
# 2        Couverture population  ...       17510               CHIVES
# 3        Couverture population  ...       17510               CHIVES
# 4        Couverture population  ...       17510               CHIVES
# ...                        ...  ...         ...                  ...
# 1097815  Couverture surfacique  ...       70130  LE PONT-DE-PLANCHES
# 1097816  Couverture surfacique  ...       70130  LE PONT-DE-PLANCHES
# 1097817  Couverture surfacique  ...       70130  LE PONT-DE-PLANCHES
# 1097818  Couverture surfacique  ...       70130  LE PONT-DE-PLANCHES
# 1097819  Couverture surfacique  ...       70130  LE PONT-DE-PLANCHES
#
#                Département            Région          Statut Altitude Moyenne  \
# 0        CHARENTE-MARITIME  POITOU-CHARENTES  Commune simple            108.0
# 1        CHARENTE-MARITIME  POITOU-CHARENTES  Commune simple            108.0
# 2        CHARENTE-MARITIME  POITOU-CHARENTES  Commune simple            108.0
# 3        CHARENTE-MARITIME  POITOU-CHARENTES  Commune simple            108.0
# 4        CHARENTE-MARITIME  POITOU-CHARENTES  Commune simple            108.0
# ...                    ...               ...             ...              ...
# 1097815        HAUTE-SAONE     FRANCHE-COMTE  Commune simple            234.0
# 1097816        HAUTE-SAONE     FRANCHE-COMTE  Commune simple            234.0
# 1097817        HAUTE-SAONE     FRANCHE-COMTE  Commune simple            234.0
# 1097818        HAUTE-SAONE     FRANCHE-COMTE  Commune simple            234.0
# 1097819        HAUTE-SAONE     FRANCHE-COMTE  Commune simple            234.0
#
#          Superficie  Population                    geo_point_2d  \
# 0            2062.0         0.4  45.9508835378, -0.121918052323
# 1            2062.0         0.4  45.9508835378, -0.121918052323
# 2            2062.0         0.4  45.9508835378, -0.121918052323
# 3            2062.0         0.4  45.9508835378, -0.121918052323
# 4            2062.0         0.4  45.9508835378, -0.121918052323
# ...             ...         ...                             ...
# 1097815       690.0         0.2    47.5374721676, 5.92263244824
# 1097816       690.0         0.2    47.5374721676, 5.92263244824
# 1097817       690.0         0.2    47.5374721676, 5.92263244824
# 1097818       690.0         0.2    47.5374721676, 5.92263244824
# 1097819       690.0         0.2    47.5374721676, 5.92263244824
#
#                                                  geo_shape
# 0        {"type": "Polygon", "coordinates": [[[-0.10484...
# 1        {"type": "Polygon", "coordinates": [[[-0.10484...
# 2        {"type": "Polygon", "coordinates": [[[-0.10484...
# 3        {"type": "Polygon", "coordinates": [[[-0.10484...
# 4        {"type": "Polygon", "coordinates": [[[-0.10484...
# ...                                                    ...
# 1097815  {"type": "Polygon", "coordinates": [[[5.938235...
# 1097816  {"type": "Polygon", "coordinates": [[[5.938235...
# 1097817  {"type": "Polygon", "coordinates": [[[5.938235...
# 1097818  {"type": "Polygon", "coordinates": [[[5.938235...
# 1097819  {"type": "Polygon", "coordinates": [[[5.938235...
#
# [1097820 rows x 21 columns]

# %%
# 6) Pour quels statut et opérateur a-t-on la couverture la plus faible ?
# Pour le réseau 4G et la couverture surfacique, calculez la moyenne des couvertures par statut de commune et par opérateur.
# Pour quel couple (statut, opérateur) a-t-on la moyenne de la couverture la plus faible ?
def data_get_worst_statut_operateur():
    df = data_join_geo()
    df.loc[(df["Réseau"] == "4G") & (df["Type Couverture"] == "Couverture surfacique")]
    worst_statut_operateur = None
    return worst_statut_operateur

# %%
# data_get_worst_statut_operateur
data_get_worst_statut_operateur()

# %%
import unittest

class Lesson5Tests(unittest.TestCase):
    
    def test_01_load_data(self):
        df = load_data()
        # test shape
        self.assertEqual(df.shape, (36594, 37))
        
    def test_02_data_wide2long(self):
        df = data_wide2long()
        # test shape
        self.assertEqual(df.shape, (1097820, 9))
        
    def test_03_data_add3columns(self):
        df = data_add3columns()
        # test "Opérateur" values
        s1 = set(df['Opérateur'].unique())
        s2 = set(['Orange France', 'Bouygues Telecom', 'SFR', 'Free Mobile', 'Tout Opérateur'])
        self.assertSetEqual(s1, s2)
        # test "Type Couverture" values
        s1 = set(df['Type Couverture'].unique())
        s2 = set(['Couverture population', 'Couverture surfacique'])
        self.assertSetEqual(s1, s2)
        # test "Réseau" values
        s1 = set(df['Réseau'].unique())
        s2 = set(['2G', '3G', '4G'])
        self.assertSetEqual(s1, s2)
        
    def test_04_data_multi_index(self):
        df = data_multi_index()
        # test shape
        self.assertEqual(df.shape, (36594, 30))
        # test multi-index de l'index
        self.assertEqual(len(df.index.levels), 7)
        # test multi-index des columns
        self.assertEqual(len(df.columns.levels), 3)
        
    def test_05_data_join_geo(self):
        df = data_join_geo()
        # test length
        self.assertEqual(len(df), 1097820)
        
    def test_06_data_get_worst_statut_operateur(self):
        statut_operateur = data_get_worst_statut_operateur()
        # test length
        self.assertEqual(statut_operateur, ('Commune simple', 'Free Mobile'))

# %%
# run tests
test_suite = unittest.makeSuite(Lesson5Tests)
runner = unittest.TextTestRunner(verbosity=2)
runner.run(test_suite)
